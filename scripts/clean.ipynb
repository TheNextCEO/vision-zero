# %%
"""
goal: create clean dataset for 2018 - 2021 crashes -- "events" and "drivers"
steps:
1. import dataset
2. remove crashes that occured before 2018
3. remove crashes missing latitude and/or longitude (will be qa/qc'd)
4. remove crashes with incorrect latitude and/or longitude
5. export clean dataset as a geojson file and csv
"""
# Out:
# /Users/shelbygreen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,20,23,29,30,57,59,61,63,64) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Events Data

# %% [markdown]
# ## Import Data

# %%
# import libraries
import pandas as pd # for data manipulation
import gspread # to connect with google sheets
from df2gspread import df2gspread as d2g # to interact with google sheets
import geopandas as gpd # for geospatial data manipulation
import os # for file navigation
from datetime import date # for age calculations

# %%
# create dataframe of crashes in leon county
df = pd.read_csv("../data/semiclean/leon-events.csv")[['report_number', 'crash_year', 'crash_date_time',
                                       'first_harmful_event', 'total_number_of_vehicles', 'total_number_of_persons',
                                       'latitude', 'longitude', 'on_street_road_highway', 'street_address_number',
                                       'from_intersection_of']]
# Out:
# /Users/shelbygreen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (29,56,57,58,59,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# read YAML file
import yaml
yaml_file = open("../keys.yaml")
parsed_yaml_file = yaml.load(yaml_file)
# Out:
# <ipython-input-3-eabd164243c5>:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   parsed_yaml_file = yaml.load(yaml_file)

# %% [markdown]
# ## Filter Data

# %%
# select crashes that occured on 1/1/2010 or later
df2010 = df.query(" crash_year >= 2010").reset_index(drop=True)

# %%
# remove the rows with missing lat/lon data -- these will be addressed in qa/qc
df2010missing = df2010[df2010['latitude'].isna() | df2010['longitude'].isna()]

# %%
# export to Google Sheets for QA/QC
from oauth2client.service_account import ServiceAccountCredentials

# access and store credentials
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('./gsCredentials.json')
gc = gspread.authorize(credentials)

# connect to the Google Sheet
spreadsheet_key = parsed_yaml_file["spreadsheet_key"]
wks_name = 'missing-2018'

# send data to the Google Sheet
d2g.upload(df2018missing, spreadsheet_key, wks_name, credentials=credentials, row_names=True)
# Out:
# <Worksheet 'missing-2018' id:557274010>

# %% [markdown]
# ## Clean Data

# %%
# add column for crash date
df2010['crash_date'] = df2010['crash_date_time'].str.split(" ").str[0]

# add column for crash time
df2010['crash_time'] = df2010['crash_date_time'].str.split(" ").str[1]

# %%
# drop crash date time column
df2010 = df2010.drop(['crash_date_time'], axis=1)

# %%
# create clean dataset
df2010clean = df2010[~df2010['latitude'].isna() & ~df2010['longitude'].isna()]
#                      & ~df2018['report_number'].isin(['87845295', '24211781', '24339312'])]

# %% [markdown]
# ## Export Data

# %%
# convert to geodataframe
gdf2018clean = gpd.GeoDataFrame(df2018clean, geometry=gpd.points_from_xy(df2018clean.longitude, df2018clean.latitude))

# %%
# export to geojson
gdf2018clean.to_file("./data/clean/all-2018to2021.geojson", driver='GeoJSON')

# %%
# export to csv
df2018clean.to_csv("../data/clean/all-2018to2021.csv")

# %%
df2010clean
# Out:
#         report_number  crash_year  first_harmful_event  \
# 1            71897779        2010                 14.0
# 16           71897893        2010                 33.0
# 51           71898116        2010                 14.0
# 55           71898125        2010                 14.0
# 66           71898161        2010                 10.0
# ...               ...         ...                  ...
# 110577       90116307        2021                 14.0
# 110578       90116314        2021                 14.0
# 110579       90116316        2021                 14.0
# 110580       90116323        2021                 14.0
# 110581       90116325        2021                 14.0
#
#         total_number_of_vehicles  total_number_of_persons   latitude  \
# 1                              2                        2  30.046356
# 16                             1                        1  30.444660
# 51                             2                        2  30.463600
# 55                             2                        2  30.300099
# 66                             1                        2  30.428430
# ...                          ...                      ...        ...
# 110577                         2                        3  30.444673
# 110578                         2                        2  30.480562
# 110579                         2                        2  30.431120
# 110580                         2                        2  30.465070
# 110581                         2                        4  30.459272
#
#         longitude      on_street_road_highway street_address_number  \
# 1      -84.028192                 N Monroe St                   NaN
# 16     -84.289330  US Hwy 90 (W Tennessee St)                   NaN
# 51     -84.292090                 W Tharpe St                   NaN
# 55     -84.145080            Raymond Diehl Rd                   NaN
# 66     -84.281950                  S Adams St                   NaN
# ...           ...                         ...                   ...
# 110577 -84.285620          N M L KING JR BLVD                   NaN
# 110578 -84.236873           Capital Circle NE                   NaN
# 110579 -84.226543           Capital Circle SE                   NaN
# 110580 -84.327236                 W Tharpe St                   NaN
# 110581 -84.360786                  UNNAMED RD                   NaN
#
#           from_intersection_of  crash_date crash_time
# 1                          NaN  2010-12-10      12:00
# 16                         NaN  2010-12-10      12:34
# 51                         NaN  2010-12-24      12:36
# 55                         NaN  2010-12-25      10:15
# 66      Jakes and Patterson St  2010-12-29      15:12
# ...                        ...         ...        ...
# 110577          W TENNESSEE ST  2021-06-29      18:45
# 110578            WEDNESDAY RD  2021-06-30      12:25
# 110579        DICK WILSON BLVD  2021-06-30      11:50
# 110580                 IVAN DR  2021-06-30      16:40
# 110581          W TENNESSEE ST  2021-06-30      17:22
#
# [40265 rows x 12 columns]

# %% [markdown]
# # Misc

# %% [markdown]
# # How many car crashes have happened on Miccosukee 2018-2021?

# %%
# crashes within a bounding box
# bounding box from bboxfinder.org 

# miccosukee = df2018clean.query(' on_street_road_highway.str.contains("Miccosukee").values ')
miccosukee[miccosukee['longitude'].between(-84.277496, -84.261682) & miccosukee['latitude'].between(30.445584, 30.456165)].sort_values(["from_intersection_of", "crash_time"], ascending = [True,True])
# Out:
#        report_number  crash_year  first_harmful_event  \
# 22684       89145393        2019                 14.0
# 33044       90111729        2020                 14.0
# 26576       89147106        2020                 14.0
# 14621       87844035        2019                 14.0
# 37704       90115469        2021                 14.0
# 9133        87839457        2018                 15.0
# 15447       87844863        2019                 14.0
# 15665       87845116        2019                 14.0
# 21804       89144515        2019                 14.0
# 17409       89140096        2019                 14.0
# 17583       89140271        2019                 14.0
# 21196       89143900        2019                 14.0
# 18546       89141237        2019                 14.0
# 27653       89148186        2020                 14.0
# 27448       89147981        2020                 14.0
# 17901       89140589        2019                 14.0
# 18489       89141179        2019                 14.0
# 7907        87838227        2018                 14.0
# 14722       87844137        2019                 14.0
# 19717       89142416        2019                 14.0
# 14586       87843999        2019                 14.0
# 26445       89146972        2020                 14.0
# 14050       87843450        2019                 14.0
# 26765       89147296        2020                 14.0
# 14249       87843649        2019                 14.0
# 5984        87836289        2018                 14.0
# 6548        87836855        2018                 14.0
# 26570       89147100        2020                 14.0
# 15704       87845155        2019                 14.0
# 5788        87836094        2018                 14.0
# 1710        86964835        2018                 14.0
# 10793       87841233        2018                 14.0
# 10165       87840603        2018                 14.0
# 26516       89147045        2020                 14.0
# 18733       89141424        2019                 14.0
# 37134       90114853        2021                 14.0
# 7346        87837655        2018                 14.0
# 23914       89146603        2019                 14.0
# 16095       87845548        2019                 14.0
# 10062       87840487        2018                 14.0
# 15328       87844743        2019                 14.0
# 17724       89140412        2019                 14.0
# 33272       90111958        2020                 14.0
# 36137       90113846        2021                 14.0
# 33154       90111839        2020                 14.0
# 1093        86964215        2018                 14.0
# 1315        86964439        2018                 14.0
# 37635       90115394        2021                 14.0
# 19023       89141715        2019                 14.0
# 19335       89142027        2019                 14.0
# 35925       90113633        2021                 14.0
# 38429       90116286        2021                 39.0
# 30153       89299589        2020                 15.0
# 38112       90115909        2021                 24.0
# 36769       90114484        2021                 39.0
# 7704        87838022        2018                 14.0
# 24927       89298028        2019                 14.0
# 6137        87836443        2018                 15.0
#
#        total_number_of_vehicles  total_number_of_persons   latitude  \
# 22684                         2                        2  30.447141
# 33044                         2                        4  30.447528
# 26576                         2                        3  30.447547
# 14621                         2                        2  30.447410
# 37704                         2                        2  30.447698
# 9133                          3                        1  30.454002
# 15447                         2                        1  30.454308
# 15665                         2                        3  30.453973
# 21804                         2                        2  30.454965
# 17409                         3                        3  30.449153
# 17583                         2                        5  30.448239
# 21196                         2                        2  30.448230
# 18546                         2                        2  30.448254
# 27653                         3                        3  30.453173
# 27448                         2                        2  30.453171
# 17901                         2                       16  30.455253
# 18489                         2                        2  30.455265
# 7907                          2                        2  30.455248
# 14722                         2                        2  30.455074
# 19717                         2                        2  30.454461
# 14586                         2                        3  30.454577
# 26445                         2                        2  30.450015
# 14050                         3                        8  30.449870
# 26765                         2                        3  30.453780
# 14249                         2                        9  30.453407
# 5984                          2                        2  30.455302
# 6548                          2                        2  30.455389
# 26570                         2                        2  30.455301
# 15704                         2                       24  30.455678
# 5788                          2                        3  30.455188
# 1710                          2                        2  30.455662
# 10793                         2                        2  30.455692
# 10165                         2                        2  30.455795
# 26516                         3                        6  30.455577
# 18733                         2                        3  30.455578
# 37134                         2                        4  30.455705
# 7346                          2                        3  30.455660
# 23914                         2                        6  30.455850
# 16095                         2                        2  30.455684
# 10062                         2                        3  30.455664
# 15328                         3                        8  30.455538
# 17724                         3                        6  30.455759
# 33272                         2                        2  30.455545
# 36137                         2                        2  30.455599
# 33154                         2                        3  30.446072
# 1093                          2                        3  30.452291
# 1315                          2                        2  30.449540
# 37635                         2                        3  30.449400
# 19023                         2                        2  30.449598
# 19335                         2                        2  30.449452
# 35925                         2                        1  30.451021
# 38429                         1                        3  30.455493
# 30153                         2                        1  30.447454
# 38112                         1                        1  30.448044
# 36769                         1                        2  30.453052
# 7704                          2                        2  30.455482
# 24927                         2                        7  30.452923
# 6137                          2                        1  30.454390
#
#        longitude on_street_road_highway street_address_number  \
# 22684 -84.275703          Miccosukee Rd                   NaN
# 33044 -84.275259          Miccosukee Rd                   NaN
# 26576 -84.275260          Miccosukee Rd                   NaN
# 14621 -84.275384          Miccosukee Rd                   NaN
# 37704 -84.275053          Miccosukee Rd                   NaN
# 9133  -84.265941          Miccosukee Rd                   NaN
# 15447 -84.265222          Miccosukee Rd                   NaN
# 15665 -84.265930          Miccosukee Rd                   NaN
# 21804 -84.262323          Miccosukee Rd                   NaN
# 17409 -84.273604          Miccosukee Rd                   NaN
# 17583 -84.274548          Miccosukee Rd                   NaN
# 21196 -84.274532          Miccosukee Rd                   NaN
# 18546 -84.274501          Miccosukee Rd                   NaN
# 27653 -84.267829          Miccosukee Rd                   NaN
# 27448 -84.267701          Miccosukee Rd                   NaN
# 17901 -84.263058          Miccosukee Rd                   NaN
# 18489 -84.263106          Miccosukee Rd                   NaN
# 7907  -84.263108          Miccosukee Rd                   NaN
# 14722 -84.263548          Miccosukee Rd                   NaN
# 19717 -84.264769          Miccosukee Rd                   NaN
# 14586 -84.264524          Miccosukee Rd                   NaN
# 26445 -84.272952          Miccosukee Rd                   NaN
# 14050 -84.273026          Miccosukee Rd                   NaN
# 26765 -84.266194          Miccosukee Rd                   NaN
# 14249 -84.267095          Miccosukee Rd                   NaN
# 5984  -84.262723          Miccosukee Rd                   NaN
# 6548  -84.262650          Miccosukee Rd                   NaN
# 26570 -84.262627          Miccosukee Rd                   NaN
# 15704 -84.262071          Miccosukee Rd                   NaN
# 5788  -84.262964          Miccosukee Rd                   NaN
# 1710  -84.262180          Miccosukee Rd                   NaN
# 10793 -84.262219          Miccosukee Rd                   NaN
# 10165 -84.261953          Miccosukee Rd                   NaN
# 26516 -84.262134          Miccosukee Rd                   NaN
# 18733 -84.262361          Miccosukee Rd                   NaN
# 37134 -84.262153          Miccosukee Rd                   NaN
# 7346  -84.262187          Miccosukee Rd                   NaN
# 23914 -84.261811          Miccosukee Rd                   NaN
# 16095 -84.262187          Miccosukee Rd                   NaN
# 10062 -84.262097          Miccosukee Rd                   NaN
# 15328 -84.262357          Miccosukee Rd                   NaN
# 17724 -84.262043          Miccosukee Rd                   NaN
# 33272 -84.262403          Miccosukee Rd                   NaN
# 36137 -84.262345          Miccosukee Rd                   NaN
# 33154 -84.276923          Miccosukee Rd                   NaN
# 1093  -84.269577          Miccosukee Rd                   NaN
# 1315  -84.273241          Miccosukee Rd                   NaN
# 37635 -84.273352          Miccosukee Rd                   NaN
# 19023 -84.273193          Miccosukee Rd                   NaN
# 19335 -84.273384          Miccosukee Rd                   NaN
# 35925 -84.271509          Miccosukee Rd                   707
# 38429 -84.263170          Miccosukee Rd                  1202
# 30153 -84.275031          Miccosukee Rd                   561
# 38112 -84.274374          Miccosukee Rd                   579
# 36769 -84.266888          Miccosukee Rd                   912
# 7704  -84.263054          Miccosukee Rd                  1202
# 24927 -84.267622          Miccosukee Rd                   912
# 6137  -84.265343          Miccosukee Rd                  1108
#
#       from_intersection_of  crash_date crash_time
# 22684            CHERRY ST  2019-10-30      07:27
# 33044            CHERRY ST  2020-10-26      10:26
# 26576            CHERRY ST  2020-01-07      11:23
# 14621            CHERRY ST  2019-01-29      14:08
# 37704            CHERRY ST  2021-05-13      20:03
# 9133         CRESTVIEW AVE  2018-08-27      13:35
# 15447        CRESTVIEW AVE  2019-03-01      17:13
# 15665        CRESTVIEW AVE  2019-03-10      17:14
# 21804           DOCTORS DR  2019-10-01      11:25
# 17409         E BREVARD ST  2019-04-09      17:55
# 17583         E GEORGIA ST  2019-04-16      13:04
# 21196         E GEORGIA ST  2019-09-09      13:58
# 18546         E GEORGIA ST  2019-05-21      14:05
# 27653         HILLCREST ST  2020-02-20      11:51
# 27448         HILLCREST ST  2020-02-12      15:45
# 17901              LEE AVE  2019-04-27      08:25
# 18489              LEE AVE  2019-05-18      09:53
# 7907               LEE AVE  2018-07-05      13:13
# 14722              LEE AVE  2019-02-02      19:10
# 19717           MARION AVE  2019-07-12      13:43
# 14586           MARION AVE  2019-01-28      17:43
# 26445            MARTIN ST  2020-01-01      19:47
# 14050          MCDANIEL ST  2019-01-08      14:05
# 26765         MITCHELL AVE  2020-01-15      14:00
# 14249         MITCHELL AVE  2019-01-16      14:59
# 5984         N MAGNOLIA DR  2018-04-18      07:43
# 6548         N MAGNOLIA DR  2018-05-08      07:56
# 26570        N MAGNOLIA DR  2020-01-08      08:03
# 15704        N MAGNOLIA DR  2019-03-12      08:07
# 5788         N MAGNOLIA DR  2018-04-11      08:08
# 1710         N MAGNOLIA DR  2018-02-14      08:48
# 10793        N MAGNOLIA DR  2018-10-24      10:03
# 10165        N MAGNOLIA DR  2018-10-03      11:01
# 26516        N MAGNOLIA DR  2020-01-06      12:48
# 18733        N MAGNOLIA DR  2019-05-30      13:00
# 37134        N MAGNOLIA DR  2021-04-13      13:44
# 7346         N MAGNOLIA DR  2018-06-11      15:11
# 23914        N MAGNOLIA DR  2019-12-13      15:37
# 16095        N MAGNOLIA DR  2019-03-29      17:08
# 10062        N MAGNOLIA DR  2018-09-28      17:10
# 15328        N MAGNOLIA DR  2019-02-25      17:17
# 17724        N MAGNOLIA DR  2019-04-20      17:28
# 33272        N MAGNOLIA DR  2020-11-05      19:12
# 36137        N MAGNOLIA DR  2021-02-19      21:16
# 33154        N MERIDIAN ST  2020-10-30      23:04
# 1093            TERRACE ST  2018-01-22      15:55
# 1315            WILSON AVE  2018-01-31      13:57
# 37635           WILSON AVE  2021-05-10      13:58
# 19023           WILSON AVE  2019-06-12      15:30
# 19335           WILSON AVE  2019-06-24      22:10
# 35925                  NaN  2021-02-09      08:10
# 38429                  NaN  2021-06-29      10:41
# 30153                  NaN  2020-09-14      11:00
# 38112                  NaN  2021-06-09      11:42
# 36769                  NaN  2021-03-23      15:07
# 7704                   NaN  2018-06-25      15:36
# 24927                  NaN  2019-09-18      15:40
# 6137                   NaN  2018-04-23      15:59

# %% [markdown]
# # How many car crashes happened on Black Friday?

# %%
len(df2018.query(" crash_year == 2018 and crash_date == '2018-11-30' ").sort_values(by="crash_time", ascending=True))
# Out:
# 58

# %%
df2018.query(" crash_year == 2019 and crash_date == '2019-11-29' ").sort_values(by="crash_time", ascending=True)
# Out:
#        report_number  crash_year  first_harmful_event  \
# 16659       88151871        2019                 18.0
# 23518       89146218        2019                 25.0
# 23517       89146218        2019                 25.0
# 23516       89146217        2019                 10.0
# 25389       89298484        2019                 14.0
# 16766       88261649        2019                 28.0
# 23520       89146220        2019                 14.0
# 23519       89146219        2019                 14.0
# 23521       89146221        2019                 14.0
# 23522       89146221        2019                 14.0
# 23524       89146223        2019                 14.0
# 23523       89146222        2019                 14.0
# 25372       89298467        2019                 14.0
# 23539       89146238        2019                 14.0
# 23525       89146224        2019                 14.0
# 23527       89146226        2019                 14.0
# 23538       89146237        2019                 28.0
# 23530       89146229        2019                 14.0
# 23526       89146225        2019                 14.0
# 23531       89146230        2019                 14.0
# 23533       89146232        2019                 15.0
# 23532       89146231        2019                 14.0
# 23528       89146227        2019                 14.0
# 25377       89298472        2019                 14.0
# 23529       89146228        2019                 10.0
# 16732       88187129        2019                 14.0
# 23534       89146233        2019                 14.0
# 16733       88187130        2019                 18.0
# 25380       89298475        2019                 13.0
#
#        total_number_of_vehicles  total_number_of_persons   latitude  \
# 16659                         2                        3  30.480331
# 23518                         1                        3  30.415489
# 23517                         1                        3  30.415489
# 23516                         1                        2  30.453004
# 25389                         3                        6  30.427297
# 16766                         1                        2  30.481131
# 23520                         2                        5  30.459131
# 23519                         2                        2  30.443968
# 23521                         2                        3  30.444663
# 23522                         2                        3  30.444663
# 23524                         2                        2  30.463266
# 23523                         2                        2  30.498427
# 25372                         3                        3  30.442689
# 23539                         2                        4  30.462170
# 23525                         2                        5  30.412895
# 23527                         2                        2  30.469691
# 23538                         1                        1  30.481325
# 23530                         2                        2  30.469077
# 23526                         2                        2  30.441369
# 23531                         2                        2  30.459166
# 23533                         2                        1  30.442691
# 23532                         2                        4  30.430691
# 23528                         2                        3  30.475160
# 25377                         3                        4  30.492826
# 23529                         1                        2  30.432093
# 16732                         2                        3  30.481440
# 23534                         2                        2  30.429941
# 16733                         1                        3  30.478556
# 25380                         1                        2  30.504383
#
#        longitude        on_street_road_highway street_address_number  \
# 16659 -84.150612                        I-10 E                   NaN
# 23518 -84.301143                       MILL ST                   NaN
# 23517 -84.301143                       MILL ST                   NaN
# 23516 -84.337730                  Appleyard Dr                   NaN
# 25389 -84.226852             Capital Circle SE                   NaN
# 16766 -84.370140  INTERSTATE 10 (STATE ROAD 8)                   NaN
# 23520 -84.358870                W Tennessee St                   NaN
# 23519 -84.278338                  N Gadsden St                   NaN
# 23521 -84.278484                E Tennessee St                   NaN
# 23522 -84.278484                E Tennessee St                   NaN
# 23524 -84.277254                 N Meridian Rd                   NaN
# 23523 -84.246874             Capital Circle NE                   NaN
# 25372 -84.261841                       HAYS ST                   NaN
# 23539 -84.346408                Blountstown St                   NaN
# 23525 -84.280579                   S Monroe St                   NaN
# 23527 -84.230807             Capital Circle NE                   NaN
# 23538 -84.226851                FLEISCHMANN RD                   NaN
# 23530 -84.234143            CENTRE POINTE BLVD                  1900
# 23526 -84.337884                W Pensacola St                   NaN
# 23531 -84.360506             Capital Circle NW                   NaN
# 23533 -84.212384                  ACCESS RD 18                   NaN
# 23532 -84.245332                Apalachee Pkwy                   NaN
# 23528 -84.293822                      Allen Rd                  2373
# 25377 -84.324168                   N Monroe St                   NaN
# 23529 -84.249603                Blair Stone Rd                   NaN
# 16732 -84.313680  INTERSTATE 10 (STATE ROAD 8)                   NaN
# 23534 -84.242082                Apalachee Pkwy                  2320
# 16733 -84.144400  INTERSTATE 10 (STATE ROAD 8)                   NaN
# 25380 -84.094264                      Mahan Dr                   NaN
#
#                   from_intersection_of  crash_date crash_time
# 16659                           MM 209  2019-11-29      02:48
# 23518                    SPRINGHILL RD  2019-11-29      04:50
# 23517                    SPRINGHILL RD  2019-11-29      04:50
# 23516                   W TENNESSEE ST  2019-11-29      07:07
# 25389                   APALACHEE PKWY  2019-11-29      07:45
# 16766                     MISSION ROAD  2019-11-29      07:45
# 23520                              NaN  2019-11-29      10:30
# 23519                        E CALL ST  2019-11-29      11:12
# 23521                     N GADSDEN ST  2019-11-29      11:22
# 23522                     N GADSDEN ST  2019-11-29      11:22
# 23524                      E THARPE ST  2019-11-29      12:16
# 23523                VILLAGE GREEN WAY  2019-11-29      13:15
# 25372                    N MAGNOLIA DR  2019-11-29      13:16
# 23539                        NEKOMA LN  2019-11-29      14:46
# 23525                          POLK DR  2019-11-29      15:06
# 23527                    MICCOSUKEE RD  2019-11-29      15:32
# 23538                    WELAUNEE BLVD  2019-11-29      15:39
# 23530                              NaN  2019-11-29      15:55
# 23526                   S APPLEYARD DR  2019-11-29      15:56
# 23531                   W TENNESSEE ST  2019-11-29      16:30
# 23533                              NaN  2019-11-29      17:37
# 23532                     LINDA ANN DR  2019-11-29      17:55
# 23528                              NaN  2019-11-29      18:26
# 25377                       TALPECO RD  2019-11-29      18:35
# 23529                   APALACHEE PKWY  2019-11-29      18:47
# 16732  U.S. HIGHWAY 27 (STATE ROAD 63)  2019-11-29      19:35
# 23534                              NaN  2019-11-29      19:58
# 16733  U.S. HIGHWAY 90 (STATE ROAD 10)  2019-11-29      21:00
# 25380                          BAUM RD  2019-11-29      21:25

# %%
df2018.query(" crash_year == 2020 and crash_date == '2020-11-27' ").sort_values(by="crash_time", ascending=True)
# Out:
#        report_number  crash_year  first_harmful_event  \
# 26192       88276836        2020                 13.0
# 33641       90112339        2020                 14.0
# 33640       90112337        2020                 14.0
# 33653       90112351        2020                 14.0
# 26392       88349799        2020                 14.0
# 25588       83822610        2020                 14.0
# 26091       88260935        2020                 14.0
# 30659       89769418        2020                 37.0
# 33642       90112340        2020                 14.0
# 33643       90112341        2020                 36.0
# 26092       88260936        2020                 14.0
# 33646       90112344        2020                 14.0
# 33644       90112342        2020                 15.0
# 33648       90112346        2020                 14.0
# 30411       89299857        2020                 39.0
# 26201       88282778        2020                 14.0
# 33649       90112347        2020                 36.0
# 33645       90112343        2020                 14.0
# 30413       89299859        2020                 14.0
# 30412       89299858        2020                 14.0
# 33647       90112345        2020                 39.0
# 33651       90112349        2020                 14.0
# 30423       89299869        2020                 18.0
# 30415       89299861        2020                 14.0
# 33639       90112336        2020                 14.0
#
#        total_number_of_vehicles  total_number_of_persons   latitude  \
# 26192                         1                        4  30.495797
# 33641                         2                        3  30.456258
# 33640                         2                        5  30.461008
# 33653                         2                        2  30.542517
# 26392                         2                        2  30.489695
# 25588                         3                        5  30.487501
# 26091                         2                        3  30.484682
# 30659                         1                        0  30.437897
# 33642                         2                        5  30.412602
# 33643                         1                        2  30.443816
# 26092                         1                        1  30.484940
# 33646                         2                        2  30.452705
# 33644                         2                        2  30.431493
# 33648                         2                        2  30.478006
# 30411                         1                        1  30.437150
# 26201                         2                        2  30.488562
# 33649                         1                        1  30.470728
# 33645                         3                        3  30.451794
# 30413                         2                        3  30.421024
# 30412                         2                        5  30.421030
# 33647                         1                        4  30.446426
# 33651                         2                        2  30.436743
# 30423                         1                        1  30.503337
# 30415                         2                        2  30.561664
# 33639                         2                        3  30.457108
#
#        longitude                         on_street_road_highway  \
# 26192 -84.174679                   INTERSTATE 10 (STATE ROAD 8)
# 33641 -84.276484                                   N Gadsden St
# 33640 -84.225636                                       Mahan Dr
# 33653 -84.228066                                 Thomasville Rd
# 26392 -84.164890         INTERSTATE 10 (STATE ROAD 8) MM 209 WB
# 25588 -84.161654                                  INTERSTATE 10
# 26091 -84.157933                   INTERSTATE 10 (STATE ROAD 8)
# 30659 -84.309217                                  Belle Vue Way
# 33642 -84.305676                                   W Orange Ave
# 33643 -84.249778                               N Blair Stone Rd
# 26092 -84.396110  IINTERSTATE 10 (STATE ROAD 8) 194 MILE MARKER
# 33646 -84.248404                                       Mahan Dr
# 33644 -84.225436                               Dick Wilson Blvd
# 33648 -84.313799                                      Pullen Rd
# 30411 -84.514482                                Blountstown Hwy
# 26201 -84.320024                U.S. HIGHWAY 27 (STATE ROAD 63)
# 33649 -84.344255                                 MISSION RUN CT
# 33645 -84.226416                              Capital Circle NE
# 30413 -84.228822                              Capital Circle SE
# 30412 -84.228755                              Capital Circle SE
# 33647 -84.298593                                 W Tennessee St
# 33651 -84.280726                                    S Monroe St
# 30423 -84.322888                                     CROWDER RD
# 30415 -84.217749                                 Thomasville Rd
# 33639 -84.366849                                 W Tennessee St
#
#       street_address_number             from_intersection_of  crash_date  \
# 26192                   NaN    US HIGHWAY 90 (STATE ROAD 10)  2020-11-27
# 33641                     5                        E 6TH AVE  2020-11-27
# 33640                   NaN                   CAPITAL CIR NE  2020-11-27
# 33653                   NaN                KERRY FOREST PKWY  2020-11-27
# 26392                   NaN                 US 90 (MAHAN RD)  2020-11-27
# 25588                   NaN           209MM WB ENTRANCE RAMP  2020-11-27
# 26091                   NaN  U.S. HIGHWAY 90 (STATE ROAD 10)  2020-11-27
# 30659                  1607                        RIVOLI RD  2020-11-27
# 33642                   NaN                   LAKE MUNSON ST  2020-11-27
# 33643                   NaN                   BLAIR STONE RD  2020-11-27
# 26092                   NaN  U.S. HIGHWAY 90 (STATE ROAD 10)  2020-11-27
# 33646                   NaN                 N BLAIR STONE RD  2020-11-27
# 33644                   NaN                              NaN  2020-11-27
# 33648                   NaN                OLD BAINBRIDGE RD  2020-11-27
# 30411                 15094                              NaN  2020-11-27
# 26201                   NaN                   HOMEWOOD DRIVE  2020-11-27
# 33649                   NaN                     N MISSION RD  2020-11-27
# 33645                   NaN                    EASTERWOOD DR  2020-11-27
# 30413                   NaN           OLD SAINT AUGUSTINE RD  2020-11-27
# 30412                   NaN           OLD SAINT AUGUSTINE RD  2020-11-27
# 33647                   NaN                   N WOODWARD AVE  2020-11-27
# 33651                   NaN                     E MADISON ST  2020-11-27
# 30423                   NaN                BENTON HAMPTON CT  2020-11-27
# 30415                  6706                              NaN  2020-11-27
# 33639                   NaN           TENNESSEE CAPITAL BLVD  2020-11-27
#
#       crash_time
# 26192      00:00
# 33641      10:35
# 33640      11:03
# 33653      11:19
# 26392      12:00
# 25588      12:33
# 26091      12:45
# 30659      14:51
# 33642      15:08
# 33643      15:22
# 26092      16:27
# 33646      16:40
# 33644      17:09
# 33648      17:53
# 30411      17:57
# 26201      18:25
# 33649      19:11
# 33645      19:18
# 30413      19:50
# 30412      19:50
# 33647      21:33
# 33651      21:46
# 30423      21:50
# 30415      22:35
# 33639      22:45

# %%
test_df.groupby('crash_year').count().sort_values(ascending=False, by="report_number")
#.query(" report_number == 90115367 ")
# pd.options.display.max_columns = 999

# driver_distraction_code
# driver_condition_code
# address
# city
# zip code
# date of birth
# sex
# helmet_code
# air_bag_deployment_code
# ejected
# suspected_alcohol_use_code
# suspected_drug_use_code
# injurty_severity
# ems_transport_type
# driver_action_1

# how many visitors/out-of-towners get into car accidents?
# Out:
#             report_number  vehicle_number  person_number  recommend_re_exam  \
# crash_year
# 2018              1329812         1329812        1329812            1134582
#
#             driver_license_state  dl_expiration_date  driver_license_type  \
# crash_year
# 2018                     1285358             1271135              1290593
#
#             driver_distraction_code  driver_condition_code  \
# crash_year
# 2018                        1320563                1319423
#
#             required_endorsements  vision_obstructed  insurance_company  \
# crash_year
# 2018                      1011907            1296655            1303474
#
#                city    state  zip_code  date_of_birth      sex  helmet_code  \
# crash_year
# 2018        1305706  1302528   1300361        1284898  1309237       337510
#
#             restraint_system_code  eye_protection_code  \
# crash_year
# 2018                      1295624               795041
#
#             air_bag_deployment_code  ejected  suspected_alcohol_use_code  \
# crash_year
# 2018                        1293698  1315753                     1319572
#
#             alc_tested_code  alc_test_type_code  alc_test_results  \
# crash_year
# 2018                 504084               11254             11003
#
#             blood_alcohol_content  suspected_drug_use_code  drug_tested_code  \
# crash_year
# 2018                         6991                  1319245            498962
#
#             drug_test_type_code  drug_test_results  injury_severity  \
# crash_year
# 2018                       3894               3724          1302700
#
#             ems_transport_type  ems_name  ems_run_number  \
# crash_year
# 2018                   1305247    123672           75720
#
#             injured_taken_location  seat_position_code  row_position_code  \
# crash_year
# 2018                         96159             1318754            1317533
#
#             other_position_code  driver_action_1  driver_action_2  \
# crash_year
# 2018                     714258          1307302            53119
#
#             driver_action_3  driver_action_4
# crash_year
# 2018                  16583            10773

# %%
# df2018.groupby('first_harmful_event').count().sort_values(ascending=False, by="report_number")
# df2018.groupby('crash_year').count().sort_values(ascending=False, by="report_number")

# first harmful event
# 14 - motor vehicle in transport (another car)
# 15 - parked motor vehicle
# 39 - "Other Fixed Object (wall, building, tunnel, etc.)"
# 18 - Other Non-Fixed Object
# 32 - Tree (standing)
# 10 - Pedestrian
# 36 - "Other Post, Pole or Support"
# 11 - pedalcycle

# %% [markdown]
# # Drivers data
# report number -- there could be multiple drivers under one report number

# %% [markdown]
# ## Import Data

# %%
# define path where the driver tables are stored
path = "../data/raw/"

# create empty list
li = []

# for loop -- loop through each file and save the data
for filename in os.listdir(path):
    temp_df = pd.read_csv(os.path.join(path, filename), index_col=None, header=0) \
    .drop(['dl_number', 'policy_number', 'first_name', 'middle_name', 'last_name', 'suffix', 'phone_number', 'address'], axis=1)
    li.append(temp_df)
    
# create dataframe for the drivers table, 2018 - 2021
driver_df = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# ## Filter Data

# %%
# create list of record numbers from the events table
id_list = list(df2018['report_number'])

# %%
# remove rows from the list that don't match the ones from the events table
driver_df = driver_df.query(" report_number in @id_list")

# %%
driver_df
# Out:
#          report_number  crash_year  vehicle_number  person_number  \
# 9             87503393        2018               1              1
# 10            87503393        2018               2              2
# 397           87503396        2018               1              1
# 398           87503397        2018               1              1
# 399           87503397        2018               2              2
# ...                ...         ...             ...            ...
# 4315689       90115800        2021               1              1
# 4315690       90115802        2021               1              1
# 4315691       90115802        2021               2              2
# 4315692       90115805        2021               1              1
# 4315693       90115805        2021               2              2
#
#          recommend_re_exam driver_license_state dl_expiration_date  \
# 9                      1.0                   FL          08-JUN-24
# 10                     1.0                   FL          08-JUL-25
# 397                    1.0                   VA          15-JAN-24
# 398                    1.0                   FL          28-JAN-25
# 399                    1.0                   FL          23-MAY-20
# ...                    ...                  ...                ...
# 4315689                1.0                   FL          03-AUG-28
# 4315690                1.0                   FL          24-DEC-27
# 4315691                1.0                   FL          09-DEC-28
# 4315692                1.0                   FL          06-JUL-21
# 4315693                1.0                   FL          11-AUG-28
#
#          driver_license_type  driver_distraction_code  driver_condition_code  \
# 9                        5.0                      1.0                    1.0
# 10                       5.0                      1.0                    1.0
# 397                      5.0                      1.0                    1.0
# 398                      5.0                      1.0                    1.0
# 399                      5.0                      1.0                    1.0
# ...                      ...                      ...                    ...
# 4315689                  5.0                      1.0                    1.0
# 4315690                  5.0                      4.0                    1.0
# 4315691                  5.0                      1.0                    1.0
# 4315692                  5.0                      1.0                    1.0
# 4315693                  5.0                      1.0                    1.0
#
#          ...  ems_name  ems_run_number injured_taken_location  \
# 9        ...       NaN             NaN                    NaN
# 10       ...       NaN             NaN                    NaN
# 397      ...       NaN             NaN                    NaN
# 398      ...       NaN             NaN                    NaN
# 399      ...       NaN             NaN                    NaN
# ...      ...       ...             ...                    ...
# 4315689  ...       NaN             NaN                    NaN
# 4315690  ...       NaN             NaN                    NaN
# 4315691  ...       NaN             NaN                    NaN
# 4315692  ...       NaN             NaN                    NaN
# 4315693  ...     LCEMS      21-0020919               TMH MAIN
#
#         seat_position_code row_position_code other_position_code  \
# 9                      1.0               1.0                 NaN
# 10                     1.0               1.0                 NaN
# 397                    1.0               1.0                 NaN
# 398                    1.0               1.0                 NaN
# 399                    1.0               1.0                 NaN
# ...                    ...               ...                 ...
# 4315689                1.0               1.0                 NaN
# 4315690                1.0               1.0                 NaN
# 4315691                1.0               1.0                 1.0
# 4315692                1.0               1.0                 1.0
# 4315693                1.0               1.0                 1.0
#
#         driver_action_1  driver_action_2  driver_action_3  driver_action_4
# 9                   4.0              NaN              NaN              NaN
# 10                  1.0              NaN              NaN              NaN
# 397                 2.0              NaN              NaN              NaN
# 398                10.0              NaN              NaN              NaN
# 399                 1.0              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 4315689             3.0              NaN              NaN              NaN
# 4315690             2.0              NaN              NaN              NaN
# 4315691             1.0              NaN              NaN              NaN
# 4315692             3.0              NaN              NaN              NaN
# 4315693             1.0              NaN              NaN              NaN
#
# [68096 rows x 44 columns]

# %% [markdown]
# ## Clean Data

# %%
# change date of birth type to date

# %%
# create age of driver column

# %%
# create determine age function
def calculateAge(birthDate):
    today = date.today()
    age = today.year - birthDate.year - ((today.month, today.day) < (birthDate.month, birthDate.day))
 
    return age
